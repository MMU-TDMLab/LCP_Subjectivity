# %%
import pandas
import nltk
from nltk.corpus import wordnet
import math

# %%
df = pandas.read_pickle("lcp_2021.pkl")

# %%
df['synset_count'] = df.token.apply(lambda x : len(wordnet.synsets(str(x))))

# %%
def get_wn_depth(token):
    synsets = wordnet.synsets(str(token))
    if len(synsets) > 0:
        return synsets[0].max_depth()
    else:
        return 0

df['wn_depth'] = df.token.apply(lambda x : get_wn_depth(x))

# %%
def get_hyponyms(token):
    synsets = wordnet.synsets(str(token))
    if len(synsets) > 0:
        return len(synsets[0].hyponyms())
    else:
        return 0

df['hyponym_count'] = df.token.apply(lambda x : get_hyponyms(x))

# %%
# to run this you will need a copy of the Web1T unigrams vocab_cs file

vocab_cs_path = ""

web_1T = {}
with open(vocab_cs_path,'r') as f:
    for line in f.readlines():
        split = line.split("\t")
        web_1T[split[0]] = int(split[1])

def get_web1t_freq(token, log=False):
    freq = 0
    if token in web_1T:
        freq = web_1T[token]
    return math.log(freq+1) if log else freq 


df['web_1t'] = df.token.apply(lambda x : get_web1t_freq(x))
df['log_web_1t'] = df.token.apply(lambda x : get_web1t_freq(x, True))

# %%
# to run this you will need a copy of the file: SUBTLEXus74286wordstextversion.txt

subtlex_path = ""

subtlex = {}
with open(subtlex_path,'r') as f:
    for line in f.readlines()[1:]:
        split = line.split("\t")
        subtlex[split[0]] = int(split[1])

def get_subtlex_freq(token, log=False):
    freq = 0
    if token in subtlex:
        freq = subtlex[token]
    return math.log(freq+1) if log else freq 


df['subtlex'] = df.token.apply(lambda x : get_subtlex_freq(x))
df['log_subtlex'] = df.token.apply(lambda x : get_subtlex_freq(x, True))

# %%
from wonderlic_nlp import WonderlicNLP
from tqdm.notebook import tqdm

# %%
wnlp = WonderlicNLP()

ftrs = wnlp.analyze("cat")

# %%
fam = []
img = []
cnc = []
aoa = []

for token in tqdm(df.token.to_list()):
    ftrs = wnlp.analyze(str(token))
    fam.append(ftrs['mrc']['Fam'])
    img.append(ftrs['mrc']['Imag'])
    cnc.append(ftrs['mrc']['Conc'])
    aoa.append(ftrs['mrc']['AOA'])
# Out:
#   0%|          | 0/10800 [00:00<?, ?it/s]

# %%
df['familiarity'] = fam
df['imageability'] = img
df['concreteness'] = cnc
df['ageOfAcqu'] = aoa

# %%
df.corr()
# Out:
#                anno_count  complexity  subjectivity  synset_count  wn_depth  \
# anno_count       1.000000   -0.006157      0.002166     -0.000456 -0.007995
# complexity      -0.006157    1.000000      0.641457     -0.386950 -0.229183
# subjectivity     0.002166    0.641457      1.000000     -0.264912 -0.093522
# synset_count    -0.000456   -0.386950     -0.264912      1.000000  0.240944
# wn_depth        -0.007995   -0.229183     -0.093522      0.240944  1.000000
# hyponym_count   -0.000673   -0.197414     -0.166773      0.102879  0.076729
# web_1t           0.002606   -0.330200     -0.283030      0.400755  0.072052
# log_web_1t      -0.005487   -0.443077     -0.271023      0.472291  0.679126
# subtlex         -0.001828   -0.245508     -0.222114      0.307537  0.057437
# log_subtlex     -0.004528   -0.572658     -0.412187      0.509719  0.394516
# familiarity      0.004799   -0.351407     -0.273612      0.190059 -0.126224
# imageability     0.002081   -0.331379     -0.257938      0.176753 -0.091767
# concreteness     0.001090   -0.313677     -0.244608      0.183789 -0.060004
# ageOfAcqu        0.000528   -0.192058     -0.143811      0.083268 -0.055689
#
#                hyponym_count    web_1t  log_web_1t   subtlex  log_subtlex  \
# anno_count         -0.000673  0.002606   -0.005487 -0.001828    -0.004528
# complexity         -0.197414 -0.330200   -0.443077 -0.245508    -0.572658
# subjectivity       -0.166773 -0.283030   -0.271023 -0.222114    -0.412187
# synset_count        0.102879  0.400755    0.472291  0.307537     0.509719
# wn_depth            0.076729  0.072052    0.679126  0.057437     0.394516
# hyponym_count       1.000000  0.158838    0.198561  0.089666     0.196264
# web_1t              0.158838  1.000000    0.386450  0.454876     0.417500
# log_web_1t          0.198561  0.386450    1.000000  0.230239     0.668821
# subtlex             0.089666  0.454876    0.230239  1.000000     0.488809
# log_subtlex         0.196264  0.417500    0.668821  0.488809     1.000000
# familiarity         0.083040  0.264040   -0.002807  0.234322     0.238510
# imageability        0.084203  0.219275   -0.005348  0.219372     0.226166
# concreteness        0.099790  0.217878    0.019663  0.209361     0.229902
# ageOfAcqu           0.034594  0.141981    0.036421  0.052384     0.143873
#
#                familiarity  imageability  concreteness  ageOfAcqu
# anno_count        0.004799      0.002081      0.001090   0.000528
# complexity       -0.351407     -0.331379     -0.313677  -0.192058
# subjectivity     -0.273612     -0.257938     -0.244608  -0.143811
# synset_count      0.190059      0.176753      0.183789   0.083268
# wn_depth         -0.126224     -0.091767     -0.060004  -0.055689
# hyponym_count     0.083040      0.084203      0.099790   0.034594
# web_1t            0.264040      0.219275      0.217878   0.141981
# log_web_1t       -0.002807     -0.005348      0.019663   0.036421
# subtlex           0.234322      0.219372      0.209361   0.052384
# log_subtlex       0.238510      0.226166      0.229902   0.143873
# familiarity       1.000000      0.961350      0.911726   0.630943
# imageability      0.961350      1.000000      0.965179   0.593503
# concreteness      0.911726      0.965179      1.000000   0.605484
# ageOfAcqu         0.630943      0.593503      0.605484   1.000000

# %%
df.to_pickle("lcp_ftrs.pkl")
